# %% [markdown]
# This will serve as the sandbox, so smash the castles you don't need anymore alicia

# %%
# let's create our final data set:

import pandas as pd

from project_functions import *
import numpy as np

# %%
# cities = pd.read_csv('uscities.csv')
data = pd.read_csv('music_with_lyrics.csv')

# %%
data.head()
# Out:
#                           Artist                    Song  Wave  Year  \
# 0                    Bikini Kill          Double Dare Ya     3  2014
# 1                         Gossip     Where the Girls Are     3  2001
# 2                     Bratmobile              Love Thing     3  1993
# 3                     Lunachicks       Bitterness Barbie     3  1995
# 4  Cicely Hamilton, Ethel Smyth   The March of the Women     1  1910
#
#                                               Lyrics Original Lyrics  \
# 0  [Intro]\nIs that supposed to be doing that? Ok...             NaN
# 1  [Intro]\nThat's where I'll be\nWhere the girls...             NaN
# 2  Admit it;\r\nInnocent little girls turn you on...             NaN
# 3  Why must I stand on my toes?\r\nPerfect smile ...             NaN
# 4  Shout, shout, up with your song!\nCry with the...             NaN
#
#    Unnamed: 6 Unnamed: 7
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3         NaN        NaN
# 4         NaN        NaN

# %%
data = data[['Artist','Song','Wave','Lyrics']]

# %%
data.sample(5)
# Out:
#                   Artist                  Song  Wave  \
# 26  Gertrude "Ma" Rainey      Cell Bound Blues     1
# 19               Beyonce          Pretty Hurts     3
# 67        Billie Eilish   What Was I Made For?     3
# 46     Alanis Morissette       You Oughta Know     2
# 0            Bikini Kill        Double Dare Ya     3
#
#                                                Lyrics
# 26  [Verse 1]\r\nHey, hey, jailer, tell me what ha...
# 19  [Intro: Harvey Keitel & Beyoncé]\r\nMs. Third ...
# 67  [Verse 1]\nI used to float, now I just fall do...
# 46  [Verse 1]\nI want you to know that I'm happy f...
# 0   [Intro]\nIs that supposed to be doing that? Ok...

# %%
# one issue i see will be all the newline characters, but we can filter those out: 

data['Lyrics'] = data['Lyrics'].str.replace(pat = '[ \n|\r|\t]', repl = ' ', regex = True)

# %%
# cool, not let's get rid of all the verses and such: 
pattern = '\[\w+\s?\w*\s?\d?\]'

data['Lyrics'] = data['Lyrics'].str.replace(pat = pattern, repl = '', regex = True)

# %%
# let's also drop lyrics with no data for this visualization: 

data = data[data['Lyrics'] != 'NODATA ']

# %%
# okay now let's get lyrics as one string if we can:

# %%
wave1_all_lyrics = data[data['Wave'] == 1]['Lyrics'].sum()
wave2_all_lyrics = data[data['Wave'] == 2]['Lyrics'].sum()
wave3_all_lyrics = data[data['Wave'] == 3]['Lyrics'].sum()

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.util import bigrams

# %%
stop_words = set(stopwords.words('english'))

# %%
word_tokenize(wave1_all_lyrics)
# Out:
# ['Shout',
#  ',',
#  'shout',
#  ',',
#  'up',
#  'with',
#  'your',
#  'song',
#  '!',
#  'Cry',
#  'with',
#  'the',
#  'wind',
#  ',',
#  'for',
#  'the',
#  'dawn',
#  'is',
#  'breaking',
#  'March',
#  ',',
#  'march',
#  ',',
#  'swing',
#  'you',
#  'along',
#  'Wide',
#  'blows',
#  'our',
#  'banner',
#  ',',
#  'and',
#  'hope',
#  'is',
#  'waking',
#  'Song',
#  'with',
#  'its',
#  'story',
#  ',',
#  'dreams',
#  'with',
#  'their',
#  'glory',
#  '``',
#  'Lo',
#  '!',
#  "''",
#  'they',
#  'call',
#  ',',
#  'and',
#  'glad',
#  'is',
#  'their',
#  'word',
#  '!',
#  'Loud',
#  'and',
#  'louder',
#  'it',
#  'swells',
#  'Thunder',
#  'of',
#  'freedom',
#  ',',
#  'the',
#  'voice',
#  'of',
#  'the',
#  'Lord',
#  '!',
#  'Long',
#  ',',
#  'long—we',
#  'in',
#  'the',
#  'past',
#  'Cowered',
#  'in',
#  'dread',
#  'from',
#  'the',
#  'light',
#  'of',
#  'heaven',
#  'Strong',
#  ',',
#  'strong—stand',
#  'we',
#  'at',
#  'last',
#  'Fearless',
#  'in',
#  'faith',
#  'and',
#  'with',
#  'sight',
#  'new',
#  'given',
#  'Strength',
#  'with',
#  'its',
#  'beauty',
#  ',',
#  'life',
#  'with',
#  'its',
#  'duty',
#  '(',
#  'Hear',
#  'the',
#  'voice',
#  ',',
#  'oh',
#  'hear',
#  'and',
#  'obey',
#  '!',
#  ')',
#  'These',
#  ',',
#  'these—beckon',
#  'us',
#  'on',
#  '!',
#  'Open',
#  'your',
#  'eyes',
#  'to',
#  'the',
#  'blaze',
#  'of',
#  'day',
#  'Comrades—ye',
#  'who',
#  'have',
#  'dared',
#  'First',
#  'in',
#  'the',
#  'battle',
#  'to',
#  'strive',
#  'and',
#  'sorrow',
#  '!',
#  'Scorned',
#  ',',
#  'spurned—nought',
#  'have',
#  'ye',
#  'cared',
#  'Raising',
#  'your',
#  'eyes',
#  'to',
#  'a',
#  'wider',
#  'morrow',
#  'Ways',
#  'that',
#  'are',
#  'weary',
#  ',',
#  'days',
#  'that',
#  'are',
#  'dreary',
#  'Toil',
#  'and',
#  'pain',
#  'by',
#  'faith',
#  'ye',
#  'have',
#  'borne',
#  'Hail',
#  ',',
#  'hail—victors',
#  'ye',
#  'stand',
#  'Wearing',
#  'the',
#  'wreath',
#  'that',
#  'the',
#  'brave',
#  'have',
#  'worn',
#  '!',
#  'Life',
#  ',',
#  'strife—those',
#  'two',
#  'are',
#  'one',
#  'Naught',
#  'can',
#  'ye',
#  'win',
#  'but',
#  'by',
#  'faith',
#  'and',
#  'daring',
#  'On',
#  ',',
#  'on—that',
#  'ye',
#  'have',
#  'done',
#  'But',
#  'for',
#  'the',
#  'work',
#  'of',
#  'today',
#  'preparing',
#  'Firm',
#  'in',
#  'reliance',
#  ',',
#  'laugh',
#  'a',
#  'defiance',
#  '(',
#  'Laugh',
#  'in',
#  'hope',
#  ',',
#  'for',
#  'sure',
#  'is',
#  'the',
#  'end',
#  ')',
#  'March',
#  ',',
#  'march—many',
#  'as',
#  'one',
#  'Shoulder',
#  'to',
#  'shoulder',
#  'and',
#  'friend',
#  'to',
#  'friendOh',
#  'say',
#  ',',
#  'have',
#  'you',
#  'heard',
#  'of',
#  'the',
#  'new',
#  ',',
#  'dawning',
#  'light',
#  ',',
#  'Bringing',
#  'hope',
#  'to',
#  'our',
#  'land',
#  ',',
#  'and',
#  'its',
#  'foes',
#  'all',
#  'surprising',
#  '?',
#  'Our',
#  'banner',
#  'still',
#  'floats',
#  ',',
#  'as',
#  'the',
#  'emblem',
#  'of',
#  'right',
#  ',',
#  'And',
#  'the',
#  'day',
#  'breaks',
#  'upon',
#  'us',
#  ',',
#  'for',
#  'women',
#  'are',
#  'rising',
#  '.',
#  'And',
#  'with',
#  'ballots',
#  'in',
#  'hand',
#  ',',
#  'at',
#  'the',
#  'right',
#  '’',
#  's',
#  'dear',
#  'command',
#  ',',
#  'They',
#  '’',
#  'll',
#  'be',
#  'true',
#  'to',
#  'the',
#  'flag',
#  'and',
#  'will',
#  'rescue',
#  'our',
#  'land',
#  ';',
#  'And',
#  'ever',
#  'the',
#  'EQUAL-RIGHTS',
#  'BANNER',
#  'shall',
#  'wave',
#  'O',
#  '’',
#  'er',
#  'the',
#  'land',
#  'of',
#  'the',
#  'free',
#  'and',
#  'the',
#  'home',
#  'of',
#  'the',
#  'brave',
#  '.',
#  'How',
#  'justice',
#  'and',
#  'right',
#  'have',
#  'been',
#  'crushed',
#  'to',
#  'the',
#  'dust',
#  ',',
#  'While',
#  'the',
#  'foe',
#  'of',
#  'the',
#  'home',
#  'in',
#  'protection',
#  'reposes',
#  ';',
#  'Behind',
#  'screens',
#  ',',
#  'behind',
#  'bars',
#  ',',
#  'and',
#  'in',
#  'places',
#  'of',
#  'trust',
#  ',',
#  'Not',
#  'true',
#  'Freedom',
#  ',',
#  'but',
#  'License',
#  'its',
#  'vile',
#  'form',
#  'discloses',
#  '.',
#  'The',
#  'injustice',
#  'we',
#  'see',
#  ',',
#  'and',
#  'the',
#  'women',
#  'when',
#  'free',
#  'Will',
#  'destroy',
#  'by',
#  'the',
#  'votes',
#  ',',
#  'and',
#  'then',
#  'saved',
#  'shall',
#  'we',
#  'be',
#  ';',
#  'And',
#  'the',
#  'EQUAL-RIGHTS',
#  'BANNER',
#  'forever',
#  'shall',
#  'wave',
#  'O',
#  '’',
#  'er',
#  'the',
#  'land',
#  'of',
#  'the',
#  'free',
#  ',',
#  'and',
#  'the',
#  'home',
#  'of',
#  'the',
#  'brave',
#  '.',
#  'The',
#  'women',
#  'for',
#  'truth',
#  'and',
#  'for',
#  'virtue',
#  'will',
#  'stand',
#  ',',
#  'And',
#  'the',
#  'country',
#  'be',
#  'freed',
#  'from',
#  'unjust',
#  'legislation',
#  ',',
#  'And',
#  'heav',
#  '’',
#  'n',
#  'then',
#  'will',
#  'smile',
#  'on',
#  'the',
#  'purified',
#  'land',
#  ',',
#  'And',
#  'the',
#  'Power',
#  'shall',
#  'be',
#  'praised',
#  'that',
#  'hath',
#  'kept',
#  'us',
#  'a',
#  'nation',
#  '.',
#  'Woman',
#  '’',
#  's',
#  'ballot',
#  'is',
#  'just',
#  ',',
#  'so',
#  'then',
#  'conquer',
#  'we',
#  'must',
#  ',',
#  'And',
#  'this',
#  'be',
#  'our',
#  'watchword—',
#  '“',
#  'In',
#  'God',
#  'is',
#  'Our',
#  'Trust',
#  '!',
#  '”',
#  'And',
#  'our',
#  'EQUAL-RIGHTS',
#  'BANNER',
#  'in',
#  'triumph',
#  'shall',
#  'wave',
#  'O',
#  '’',
#  'er',
#  'the',
#  'land',
#  'of',
#  'the',
#  'free',
#  'and',
#  'the',
#  'home',
#  'of',
#  'the',
#  'brave',
#  '.',
#  'Daughters',
#  'of',
#  'Freedom',
#  'arise',
#  'in',
#  'your',
#  'might',
#  ',',
#  'March',
#  'to',
#  'the',
#  'watchwords',
#  'Justice',
#  'and',
#  'Right',
#  '!',
#  'Why',
#  'will',
#  'ye',
#  'slumber',
#  '?',
#  'wake',
#  ',',
#  'O',
#  'wake',
#  '!',
#  'Lo',
#  '!',
#  'on',
#  'your',
#  'legions',
#  'light',
#  'doth',
#  'break',
#  ',',
#  'Sunder',
#  'the',
#  'fetters',
#  '``',
#  'custom',
#  "''",
#  'hath',
#  'made',
#  '!',
#  'Come',
#  'from',
#  'the',
#  'valley',
#  ',',
#  'hill',
#  'and',
#  'glade',
#  '!',
#  'Arise',
#  ',',
#  'ye',
#  'daughters',
#  'of',
#  'a',
#  'land',
#  'That',
#  'vaunts',
#  'its',
#  'liberty',
#  '!',
#  'Make',
#  'restless',
#  'rulers',
#  'understand',
#  'That',
#  'women',
#  'must',
#  'be',
#  'free',
#  ',',
#  'That',
#  'women',
#  'will',
#  'be',
#  'free',
#  '.',
#  'Hark',
#  '!',
#  'Hark',
#  '!',
#  'The',
#  'trumpet',
#  "'s",
#  'calling',
#  '!',
#  'Who',
#  "'d",
#  'be',
#  'a',
#  'laggard',
#  'in',
#  'the',
#  'fight',
#  '?',
#  'With',
#  'victory',
#  'even',
#  'now',
#  'in',
#  'sight',
#  ',',
#  'And',
#  'stubborn',
#  'foemen',
#  'backward',
#  'falling',
#  '.',
#  'CHORUS',
#  ':',
#  'To',
#  'freedom',
#  "'s",
#  'cause',
#  'till',
#  'death',
#  'We',
#  'swear',
#  'our',
#  'fealty',
#  'March',
#  'on',
#  '!',
#  'March',
#  'on',
#  '!',
#  'Face',
#  'to',
#  'the',
#  'dawn',
#  ',',
#  'The',
#  'dawn',
#  'of',
#  'liberty',
#  '.',
#  'Arise',
#  '!',
#  'Though',
#  'pain',
#  'or',
#  'loss',
#  'betide',
#  ',',
#  'Grudge',
#  'naught',
#  'of',
#  'freedom',
#  "'s",
#  'toll',
#  '.',
#  'For',
#  'what',
#  'they',
#  'loved',
#  'the',
#  'martyrs',
#  'died',
#  ';',
#  'Are',
#  'we',
#  'of',
#  'meaner',
#  'soul',
#  '?',
#  'Are',
#  'we',
#  'of',
#  'meaner',
#  'soul',
#  '?',
#  'Our',
#  'comrades',
#  ',',
#  'greatly',
#  'daring',
#  ',',
#  'Through',
#  'prison',
#  'bars',
#  'have',
#  'led',
#  'the',
#  'way',
#  ':',
#  'Who',
#  'would',
#  'not',
#  'follow',
#  'to',
#  'the',
#  'fray',
#  ',',
#  'Their',
#  'glorious',
#  'struggle',
#  'proudly',
#  'sharing',
#  '?',
#  '[',
#  'Verse',
#  '1',
#  ']',
#  'Hey',
#  ',',
#  'hey',
#  ',',
#  'jailer',
#  ',',
#  'tell',
#  'me',
#  'what',
#  'have',
#  'I',
#  'done',
#  '?',
#  'Hey',
#  ',',
#  'hey',
#  ',',
#  'jailer',
#  ',',
#  'tell',
#  'me',
#  'what',
#  'have',
#  'I',
#  'done',
#  '?',
#  'You',
#  "'ve",
#  'got',
#  'me',
#  'all',
#  'bound',
#  'in',
#  'chains',
#  ',',
#  'did',
#  'I',
#  'kill',
#  'that',
#  'woman',
#  "'s",
#  'son',
#  '?',
#  '[',
#  'Verse',
#  '2',
#  ']',
#  'All',
#  'bound',
#  'in',
#  'prison',
#  ',',
#  'all',
#  'bound',
#  'in',
#  'jail',
#  'All',
#  'bound',
#  'in',
#  'prison',
#  ',',
#  'all',
#  'bound',
#  'in',
#  'jail',
#  'Cold',
#  'iron',
#  'bars',
#  'all',
#  'around',
#  'me',
#  ',',
#  'no',
#  'one',
#  'to',
#  'go',
#  'my',
#  'bail',
#  '[',
#  'Verse',
#  '3',
#  ']',
#  'I',
#  "'ve",
#  'got',
#  'a',
#  'mother',
#  'and',
#  'father',
#  'livin',
#  "'",
#  'in',
#  'a',
#  'cottage',
#  'by',
#  'the',
#  'sea',
#  'Got',
#  'a',
#  'mother',
#  'and',
#  'father',
#  'livin',
#  "'",
#  'in',
#  'a',
#  'cottage',
#  'by',
#  'the',
#  'sea',
#  'Got',
#  'a',
#  'sister',
#  'and',
#  'brother',
#  ',',
#  'I',
#  'wonder',
#  'do',
#  'they',
#  'think',
#  'of',
#  'poor',
#  'me',
#  '?',
#  '[',
#  'Verse',
#  '4',
#  ']',
#  'I',
#  'walked',
#  'in',
#  'my',
#  'room',
#  'the',
#  'other',
#  'night',
#  'My',
#  'man',
#  'walked',
#  'in',
#  'and',
#  'begins',
#  'to',
#  'fight',
#  'I',
#  'took',
#  'my',
#  'gun',
#  'in',
#  'my',
#  'right',
#  'hand',
#  'Told',
#  'him',
#  ',',
#  'folks',
#  ',',
#  'I',
#  'do',
#  "n't",
#  'wan',
#  'na',
#  'kill',
#  'my',
#  'man',
#  'When',
#  'I',
#  'said',
#  'that',
#  ',',
#  'he',
#  'hit',
#  'me',
#  "'cross",
#  'my',
#  'head',
#  'First',
#  'shot',
#  'I',
#  'fired',
#  ',',
#  'my',
#  'man',
#  'fell',
#  'dead',
#  'The',
#  'papers',
#  'came',
#  'out',
#  'and',
#  'told',
#  'the',
#  'news',
#  'That',
#  "'s",
#  'why',
#  'I',
#  'said',
#  'I',
#  'got',
#  'the',
#  'cell',
#  'bound',
#  'blues',
#  'Hey',
#  ',',
#  'hey',
#  ',',
#  'jailer',
#  ',',
#  'I',
#  'got',
#  'the',
#  'cell',
#  'bound',
#  'bluesLyrics',
#  '(',
#  'Spoken',
#  ':',
#  'Who',
#  "'s",
#  'that',
#  'knockin',
#  "'",
#  'on',
#  'that',
#  'door',
#  '?',
#  'Jones',
#  '?',
#  'You',
#  'better',
#  'get',
#  'away',
#  'from',
#  'that',
#  'door',
#  '.',
#  'I',
#  'do',
#  "n't",
#  'know',
#  'nobody',
#  'named',
#  'Jones',
#  '.',
#  'You',
#  "'re",
#  'in',
#  'the',
#  'right',
#  'church',
#  ',',
#  'brother',
#  ',',
#  'but',
#  'the',
#  'wrong',
#  'pew',
#  ')',
#  'Sam',
#  'Jones',
#  'left',
#  ...]

# %%
filtered = [tok for tok in word_tokenize(wave1_all_lyrics) if tok not in stop_words ]

# %%
filtered
# Out:
# ['Shout',
#  ',',
#  'shout',
#  ',',
#  'song',
#  '!',
#  'Cry',
#  'wind',
#  ',',
#  'dawn',
#  'breaking',
#  'March',
#  ',',
#  'march',
#  ',',
#  'swing',
#  'along',
#  'Wide',
#  'blows',
#  'banner',
#  ',',
#  'hope',
#  'waking',
#  'Song',
#  'story',
#  ',',
#  'dreams',
#  'glory',
#  '``',
#  'Lo',
#  '!',
#  "''",
#  'call',
#  ',',
#  'glad',
#  'word',
#  '!',
#  'Loud',
#  'louder',
#  'swells',
#  'Thunder',
#  'freedom',
#  ',',
#  'voice',
#  'Lord',
#  '!',
#  'Long',
#  ',',
#  'long—we',
#  'past',
#  'Cowered',
#  'dread',
#  'light',
#  'heaven',
#  'Strong',
#  ',',
#  'strong—stand',
#  'last',
#  'Fearless',
#  'faith',
#  'sight',
#  'new',
#  'given',
#  'Strength',
#  'beauty',
#  ',',
#  'life',
#  'duty',
#  '(',
#  'Hear',
#  'voice',
#  ',',
#  'oh',
#  'hear',
#  'obey',
#  '!',
#  ')',
#  'These',
#  ',',
#  'these—beckon',
#  'us',
#  '!',
#  'Open',
#  'eyes',
#  'blaze',
#  'day',
#  'Comrades—ye',
#  'dared',
#  'First',
#  'battle',
#  'strive',
#  'sorrow',
#  '!',
#  'Scorned',
#  ',',
#  'spurned—nought',
#  'ye',
#  'cared',
#  'Raising',
#  'eyes',
#  'wider',
#  'morrow',
#  'Ways',
#  'weary',
#  ',',
#  'days',
#  'dreary',
#  'Toil',
#  'pain',
#  'faith',
#  'ye',
#  'borne',
#  'Hail',
#  ',',
#  'hail—victors',
#  'ye',
#  'stand',
#  'Wearing',
#  'wreath',
#  'brave',
#  'worn',
#  '!',
#  'Life',
#  ',',
#  'strife—those',
#  'two',
#  'one',
#  'Naught',
#  'ye',
#  'win',
#  'faith',
#  'daring',
#  'On',
#  ',',
#  'on—that',
#  'ye',
#  'done',
#  'But',
#  'work',
#  'today',
#  'preparing',
#  'Firm',
#  'reliance',
#  ',',
#  'laugh',
#  'defiance',
#  '(',
#  'Laugh',
#  'hope',
#  ',',
#  'sure',
#  'end',
#  ')',
#  'March',
#  ',',
#  'march—many',
#  'one',
#  'Shoulder',
#  'shoulder',
#  'friend',
#  'friendOh',
#  'say',
#  ',',
#  'heard',
#  'new',
#  ',',
#  'dawning',
#  'light',
#  ',',
#  'Bringing',
#  'hope',
#  'land',
#  ',',
#  'foes',
#  'surprising',
#  '?',
#  'Our',
#  'banner',
#  'still',
#  'floats',
#  ',',
#  'emblem',
#  'right',
#  ',',
#  'And',
#  'day',
#  'breaks',
#  'upon',
#  'us',
#  ',',
#  'women',
#  'rising',
#  '.',
#  'And',
#  'ballots',
#  'hand',
#  ',',
#  'right',
#  '’',
#  'dear',
#  'command',
#  ',',
#  'They',
#  '’',
#  'true',
#  'flag',
#  'rescue',
#  'land',
#  ';',
#  'And',
#  'ever',
#  'EQUAL-RIGHTS',
#  'BANNER',
#  'shall',
#  'wave',
#  'O',
#  '’',
#  'er',
#  'land',
#  'free',
#  'home',
#  'brave',
#  '.',
#  'How',
#  'justice',
#  'right',
#  'crushed',
#  'dust',
#  ',',
#  'While',
#  'foe',
#  'home',
#  'protection',
#  'reposes',
#  ';',
#  'Behind',
#  'screens',
#  ',',
#  'behind',
#  'bars',
#  ',',
#  'places',
#  'trust',
#  ',',
#  'Not',
#  'true',
#  'Freedom',
#  ',',
#  'License',
#  'vile',
#  'form',
#  'discloses',
#  '.',
#  'The',
#  'injustice',
#  'see',
#  ',',
#  'women',
#  'free',
#  'Will',
#  'destroy',
#  'votes',
#  ',',
#  'saved',
#  'shall',
#  ';',
#  'And',
#  'EQUAL-RIGHTS',
#  'BANNER',
#  'forever',
#  'shall',
#  'wave',
#  'O',
#  '’',
#  'er',
#  'land',
#  'free',
#  ',',
#  'home',
#  'brave',
#  '.',
#  'The',
#  'women',
#  'truth',
#  'virtue',
#  'stand',
#  ',',
#  'And',
#  'country',
#  'freed',
#  'unjust',
#  'legislation',
#  ',',
#  'And',
#  'heav',
#  '’',
#  'n',
#  'smile',
#  'purified',
#  'land',
#  ',',
#  'And',
#  'Power',
#  'shall',
#  'praised',
#  'hath',
#  'kept',
#  'us',
#  'nation',
#  '.',
#  'Woman',
#  '’',
#  'ballot',
#  ',',
#  'conquer',
#  'must',
#  ',',
#  'And',
#  'watchword—',
#  '“',
#  'In',
#  'God',
#  'Our',
#  'Trust',
#  '!',
#  '”',
#  'And',
#  'EQUAL-RIGHTS',
#  'BANNER',
#  'triumph',
#  'shall',
#  'wave',
#  'O',
#  '’',
#  'er',
#  'land',
#  'free',
#  'home',
#  'brave',
#  '.',
#  'Daughters',
#  'Freedom',
#  'arise',
#  'might',
#  ',',
#  'March',
#  'watchwords',
#  'Justice',
#  'Right',
#  '!',
#  'Why',
#  'ye',
#  'slumber',
#  '?',
#  'wake',
#  ',',
#  'O',
#  'wake',
#  '!',
#  'Lo',
#  '!',
#  'legions',
#  'light',
#  'doth',
#  'break',
#  ',',
#  'Sunder',
#  'fetters',
#  '``',
#  'custom',
#  "''",
#  'hath',
#  'made',
#  '!',
#  'Come',
#  'valley',
#  ',',
#  'hill',
#  'glade',
#  '!',
#  'Arise',
#  ',',
#  'ye',
#  'daughters',
#  'land',
#  'That',
#  'vaunts',
#  'liberty',
#  '!',
#  'Make',
#  'restless',
#  'rulers',
#  'understand',
#  'That',
#  'women',
#  'must',
#  'free',
#  ',',
#  'That',
#  'women',
#  'free',
#  '.',
#  'Hark',
#  '!',
#  'Hark',
#  '!',
#  'The',
#  'trumpet',
#  "'s",
#  'calling',
#  '!',
#  'Who',
#  "'d",
#  'laggard',
#  'fight',
#  '?',
#  'With',
#  'victory',
#  'even',
#  'sight',
#  ',',
#  'And',
#  'stubborn',
#  'foemen',
#  'backward',
#  'falling',
#  '.',
#  'CHORUS',
#  ':',
#  'To',
#  'freedom',
#  "'s",
#  'cause',
#  'till',
#  'death',
#  'We',
#  'swear',
#  'fealty',
#  'March',
#  '!',
#  'March',
#  '!',
#  'Face',
#  'dawn',
#  ',',
#  'The',
#  'dawn',
#  'liberty',
#  '.',
#  'Arise',
#  '!',
#  'Though',
#  'pain',
#  'loss',
#  'betide',
#  ',',
#  'Grudge',
#  'naught',
#  'freedom',
#  "'s",
#  'toll',
#  '.',
#  'For',
#  'loved',
#  'martyrs',
#  'died',
#  ';',
#  'Are',
#  'meaner',
#  'soul',
#  '?',
#  'Are',
#  'meaner',
#  'soul',
#  '?',
#  'Our',
#  'comrades',
#  ',',
#  'greatly',
#  'daring',
#  ',',
#  'Through',
#  'prison',
#  'bars',
#  'led',
#  'way',
#  ':',
#  'Who',
#  'would',
#  'follow',
#  'fray',
#  ',',
#  'Their',
#  'glorious',
#  'struggle',
#  'proudly',
#  'sharing',
#  '?',
#  '[',
#  'Verse',
#  '1',
#  ']',
#  'Hey',
#  ',',
#  'hey',
#  ',',
#  'jailer',
#  ',',
#  'tell',
#  'I',
#  'done',
#  '?',
#  'Hey',
#  ',',
#  'hey',
#  ',',
#  'jailer',
#  ',',
#  'tell',
#  'I',
#  'done',
#  '?',
#  'You',
#  "'ve",
#  'got',
#  'bound',
#  'chains',
#  ',',
#  'I',
#  'kill',
#  'woman',
#  "'s",
#  'son',
#  '?',
#  '[',
#  'Verse',
#  '2',
#  ']',
#  'All',
#  'bound',
#  'prison',
#  ',',
#  'bound',
#  'jail',
#  'All',
#  'bound',
#  'prison',
#  ',',
#  'bound',
#  'jail',
#  'Cold',
#  'iron',
#  'bars',
#  'around',
#  ',',
#  'one',
#  'go',
#  'bail',
#  '[',
#  'Verse',
#  '3',
#  ']',
#  'I',
#  "'ve",
#  'got',
#  'mother',
#  'father',
#  'livin',
#  "'",
#  'cottage',
#  'sea',
#  'Got',
#  'mother',
#  'father',
#  'livin',
#  "'",
#  'cottage',
#  'sea',
#  'Got',
#  'sister',
#  'brother',
#  ',',
#  'I',
#  'wonder',
#  'think',
#  'poor',
#  '?',
#  '[',
#  'Verse',
#  '4',
#  ']',
#  'I',
#  'walked',
#  'room',
#  'night',
#  'My',
#  'man',
#  'walked',
#  'begins',
#  'fight',
#  'I',
#  'took',
#  'gun',
#  'right',
#  'hand',
#  'Told',
#  ',',
#  'folks',
#  ',',
#  'I',
#  "n't",
#  'wan',
#  'na',
#  'kill',
#  'man',
#  'When',
#  'I',
#  'said',
#  ',',
#  'hit',
#  "'cross",
#  'head',
#  'First',
#  'shot',
#  'I',
#  'fired',
#  ',',
#  'man',
#  'fell',
#  'dead',
#  'The',
#  'papers',
#  'came',
#  'told',
#  'news',
#  'That',
#  "'s",
#  'I',
#  'said',
#  'I',
#  'got',
#  'cell',
#  'bound',
#  'blues',
#  'Hey',
#  ',',
#  'hey',
#  ',',
#  'jailer',
#  ',',
#  'I',
#  'got',
#  'cell',
#  'bound',
#  'bluesLyrics',
#  '(',
#  'Spoken',
#  ':',
#  'Who',
#  "'s",
#  'knockin',
#  "'",
#  'door',
#  '?',
#  'Jones',
#  '?',
#  'You',
#  'better',
#  'get',
#  'away',
#  'door',
#  '.',
#  'I',
#  "n't",
#  'know',
#  'nobody',
#  'named',
#  'Jones',
#  '.',
#  'You',
#  "'re",
#  'right',
#  'church',
#  ',',
#  'brother',
#  ',',
#  'wrong',
#  'pew',
#  ')',
#  'Sam',
#  'Jones',
#  'left',
#  "lawf'ly",
#  'wife',
#  ',',
#  'step',
#  'around',
#  'Came',
#  'back',
#  'home',
#  ',',
#  "'bout",
#  'year',
#  'Took',
#  'high',
#  'brown',
#  'Went',
#  'accustomed',
#  'shore',
#  'And',
#  'knocked',
#  'knuckles',
#  'sore',
#  'His',
#  'wife',
#  'came',
#  ',',
#  'shame',
#  'She',
#  'knew',
#  'face',
#  'Sam',
#  'said',
#  ',',
#  '``',
#  'I',
#  "'m",
#  'husband',
#  ',',
#  'dear',
#  "''",
#  'But',
#  'said',
#  ',',
#  '``',
#  'Dear',
#  ',',
#  "'s",
#  'strange',
#  'hear',
#  "''",
#  'You',
#  'ai',
#  "n't",
#  'talkin',
#  "'",
#  'Mrs.',
#  'Jones',
#  'You',
#  'speakin',
#  "'",
#  'Miss',
#  'Wilson',
#  'I',
#  'used',
#  "lawf'ly",
#  'mate',
#  'But',
#  'judge',
#  'done',
#  'changed',
#  'fate',
#  'Was',
#  'time',
#  'could-a',
#  "'",
#  'walked',
#  'right',
#  'And',
#  'call',
#  'place',
#  'home',
#  'sweet',
#  'home',
#  'But',
#  "'s",
#  'mine',
#  ',',
#  'time',
#  'I',
#  "'m",
#  'free',
#  'livin',
#  "'",
#  'alone',
#  'Do',
#  "n't",
#  'need',
#  'clothes',
#  ',',
#  "n't",
#  'need',
#  'rent',
#  'Do',
#  "n't",
#  'need',
#  'ones',
#  'twos',
#  'Though',
#  'I',
#  'ai',
#  "n't",
#  'rich',
#  ',',
#  'I',
#  'know',
#  'stitch',
#  'I',
#  'earned',
#  'strutting',
#  'shoes',
#  'Say',
#  ',',
#  'hand',
#  'key',
#  'unlocks',
#  'front',
#  'door',
#  'Because',
#  'bell',
#  "n't",
#  'read',
#  'Sam',
#  'Jones',
#  ',',
#  'You',
#  'ai',
#  "n't",
#  'talkin',
#  "'",
#  'Mrs.',
#  'Jones',
#  'You',
#  'speakin',
#  "'",
#  'Miss',
#  'Wilson',
#  'nowYWomen',
#  'workers',
#  ',',
#  'women',
#  'suffering',
#  'Women',
#  'languish',
#  'home',
#  'factory',
#  ',',
#  'support',
#  'occupations',
#  ',',
#  'Why',
#  '’',
#  'help',
#  'us',
#  'build',
#  'temple',
#  'liberty',
#  ',',
#  'human',
#  'happiness',
#  '?',
#  'Help',
#  'us',
#  'raise',
#  'world',
#  'poverty',
#  'realise',
#  'want',
#  '.',
#  'Let',
#  '’',
#  'struggle',
#  'together',
#  'like',
#  'powerful',
#  'lions',
#  ',',
#  'For',
#  'liberty',
#  ',',
#  'liberty',
#  ',',
#  'ideal.There',
#  'five',
#  'a-light',
#  'us',
#  ',',
#  'In',
#  'flag',
#  'flying',
#  "o'er",
#  'us',
#  ',',
#  'There',
#  "'ll",
#  'six',
#  'next',
#  'election–',
#  'We',
#  'bring',
#  'new',
#  'star',
#  '!',
#  'We',
#  'coming',
#  'like',
#  'others',
#  ',',
#  'Free',
#  'Sisters',
#  ',',
#  'Free',
#  'Brothers',
#  ',',
#  'In',
#  'pride',
#  'affection',
#  'For',
#  'California',
#  '.',
#  'CHORUS',
#  ':',
#  'A',
#  'ballot',
#  'Lady',
#  '!',
#  'For',
#  'Home',
#  'Baby',
#  '!',
#  'Come',
#  ',',
#  'vote',
#  'ye',
#  'Lady',
#  ',',
#  'The',
#  'Baby',
#  ',',
#  'Home',
#  '!',
#  'Star',
#  'Hope',
#  'Star',
#  'Beauty',
#  '!',
#  'Of',
#  'Freedom',
#  '!',
#  'Of',
#  'Duty',
#  '!',
#  'Star',
#  'childhood',
#  "'s",
#  'new',
#  'protection',
#  ',',
#  'That',
#  'rises',
#  'high',
#  '!',
#  'We',
#  'work',
#  'together',
#  'In',
#  'golden',
#  ',',
#  'gay',
#  'weather',
#  ',',
#  'And',
#  "'ll",
#  'next',
#  'election',
#  ',',
#  'Or',
#  'know',
#  '.',
#  'CHORUS',
#  ':',
#  'A',
#  'ballot',
#  'Lady',
#  '!',
#  'For',
#  'Home',
#  'Baby',
#  '!',
#  'Come',
#  ',',
#  'vote',
#  'ye',
#  'Lady',
#  ',',
#  'The',
#  'Baby',
#  ',',
#  'Home',
#  '!',
#  ...]

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\alica\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: matplotlib in c:\users\alica\anaconda3\lib\site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: pillow in c:\users\alica\anaconda3\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\alica\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\alica\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\alica\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\alica\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\alica\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alica\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\alica\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\alica\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
import wordcloud as wc
import matplotlib.pyplot as plt

# %%
wordcloud = wc.WordCloud().generate(wave1_all_lyrics)
plt.imshow(wordcloud, interpolation = 'bilinear')

# %%
wordcloud = wc.WordCloud().generate(wave2_all_lyrics)
plt.imshow(wordcloud, interpolation = 'bilinear')

# %%
wordcloud = wc.WordCloud().generate(wave3_all_lyrics)
plt.imshow(wordcloud, interpolation = 'bilinear')
